# %% [markdown]
# <a href="https://colab.research.google.com/github/senariana09-spec/07.04/blob/main/aula_dia_17_03_PA_1f.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#entrada
a = int(input("digite um numero:"))
b = int(input("digite outro numero"))

#processamento
soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b
resto = a % b
potencia = a ** b
div_int = a // b
#saida
print(f"o resultado de {a} mais {b} é igual a : {soma}")
print(f"o resultado de {a} vezes {b} é igual a : {multiplicacao}")
print(f"o resultado da subtração de {a} menos {b} é igual a: {subtracao}")
print(f"o resultado da divisão de {a} por {b} é igual a: {divisao}")
print(f"o resultado da divisão inteira de {a} sobre {b} é igual a:")
print(f"o resultado da potenciação de {a} sobre {b} é igual a {potencia}")
# Out:
# digite um numero:35
# digite outro numero15
# o resultado de 35 mais 15 é igual a : 50
# o resultado de 35 vezes 15 é igual a : 525
# o resultado da subtração de 35 menos 15 é igual a: 20
# o resultado da divisão de 35 por 15 é igual a: 2.3333333333333335
# o resultado da divisão inteira de 35 sobre 15 é igual a:
# o resultado da potenciação de 35 sobre 15 é igual a 144884079282928466796875

# %%
# operadores
a = int(input("digite um numero"))
b = int(input("digite outro numero"))

# processamento
igual = a == b
diferente = a != b
maior = a > b
menor = a < b
menorigual = a <= b
maiorigual = a >= b

#saida
print(igual)
print(diferente)
print(maior)
print(menor)
print(menorigual)
print(maiorigual)
# Out:
# digite um numero4
# digite outro numero6
# False
# True
# False
# True
# True
# False

# %%
#codigo para transformar km em metros

#entrada
a = int(input("digite um valor em metros para transformalo em km"))
b = int(input("digite um valor em km para transformalo em metros"))

#processamento
multiplicacao = a * 1000
divisao = b / 1000

#saida
print(f"seu valor em metros {a} em km é igual a {multiplicacao} ")
print(f"seu valor em metros {b} em metros é igual a {divisao}")
# Out:
# digite um valor em metros para transformalo em km3
# digite um valor em km para transformalo em metros6
# seu valor em metros 3 em km é igual a 3000
# seu valor em metros 6 em metros é igual a 0.006
